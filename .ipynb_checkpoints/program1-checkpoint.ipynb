# %% [markdown]
# ### Program 1
# - In this assignment you will write a series of programs to solve sliding-tile puzzles using various uninformed and informed (heuristic) methods.
# - **Heuristics**, or "rules of thumb," are problem-solving methods that are based on practical experience and knowledge. They allow you to use a "quick fix" to solve a minor problem or to narrow down options.
# #### Part 1 – Reading and Validating Sliding-Puzzle Problems
# - Read a sliding-tile puzzle problem using a JSON parser.
# - Check that the sliding-tile puzzle problem is valid. Specifically, there must be fields named *n*, *start*, and *goal*. The n field must be a positive integer greater than 1. The start and goal fields must be 𝑛 x 𝑛 matrices containing the integers 0 (for the empty space) to 𝑛2 − 1

# %%
import pandas as pd

     
df1 = pd.read_json('datasets/1-move.json')
df1
# Out:
#    n      start       goal
# 0  3  [3, 1, 2]  [0, 1, 2]
# 1  3  [0, 4, 5]  [3, 4, 5]
# 2  3  [6, 7, 8]  [6, 7, 8]

# %%
import string

def validation(df: pd.DataFrame, filename: string):
    # check if n, start and goal are defined
    if(df.columns.__contains__('n') and df.columns.__contains__('start') and df.columns.__contains__('goal')):
        # check the value of n
        if(df['n'].unique()):
            nvalue = df['n'].unique()[0]
            # if n is greater than or equal to 1, proceed
            startLength = len(df['start'])
            goalLength = len(df['goal'])
            # if the start and goal columns are of length n, proceed
            if (nvalue >= 1 and startLength == nvalue and goalLength == nvalue):
                print("'n' is greater than or equal to one. 'n' is", nvalue)
                # check the start and goal columns
                # if they are of size n AND contain a zero, proceed 
                for row,row2 in zip(df['start'],df['goal']):
                    if len(row) == nvalue and len(row2) == nvalue: 
                        if 0 in row or 0 in row2:
                            print('0 found in', row,row2)
            print(f'{filename} is valid' )
        else:
            print(f'{filename} is not valid. n is not greather than or equal to one.') 
    else:
        print(f"{filename} is not valid.JSON file does not contain fields 'n', 'start', or 'goal'")

validation(df1, '1-move.json')
test_state = [[7, 2, 4],[5, 0, 6],[8, 3, 1]]
goal = [[0, 1, 2], [3, 4, 5], [6, 7, 8]]
testdf = pd.DataFrame({'n': [3,3,3], 'start': test_state, 'goal': goal})
validation(testdf, "testdf")
# Out:
# 'n' is greater than or equal to one. 'n' is 3
# 0 found in [3, 1, 2] [0, 1, 2]
# 0 found in [0, 4, 5] [3, 4, 5]
# 1-move.json is valid
# 'n' is greater than or equal to one. 'n' is 3
# 0 found in [7, 2, 4] [0, 1, 2]
# 0 found in [5, 0, 6] [3, 4, 5]
# testdf is valid

# %% [markdown]
# #### Part 2 – Sliding-Tile Puzzle Rules
# - Given a sliding-tile puzzle state, you must be able to determine the rules that are applicable to that state that can be used to generate its successor states.
# - A rule has three parts:
#     - *name* – a simple name for the rule (e.g., up, left, down, right)
#     - *precondition function* – a Boolean function that accepts a state and returns true if the rule is applicable to state
#     - *action function* – a function that accepts a state and returns the successor state obtained by applying the rule

# %%
from typing import List
from copy import deepcopy

def find_zero(state: pd.DataFrame): 
    for i, row in enumerate(state['start']):
        if 0 in row:
            return i, row.index(0)

def swap(state: pd.DataFrame, pos1, pos2):
    new_state = deepcopy(state['start'].tolist())   
    new_state[pos1[0]][pos1[1]], new_state[pos2[0]][pos2[1]] = new_state[pos2[0]][pos2[1]], new_state[pos1[0]][pos1[1]]
    return pd.DataFrame({'start': new_state})

def copy_state(state: pd.DataFrame):
    return state.copy()


def applicable_moves(state:pd.DataFrame) -> List[str]:
    # tuple = (index of row with 0, index of 0 in the row)
    zero_position = find_zero(state)
    zero_row = state['start'][zero_position[0]]
    moves = []

    # move right
    if zero_position[1] < len(zero_row) - 1:
        moves.append('Right') 
    # move left
    if zero_position[1] > 0:
        moves.append('Left') 
    # move up   
    if zero_position[0] > 0:
        moves.append('Up') 
    # move down
    if zero_position[0] < len(state) - 1: 
        moves.append('Down') 

    return moves

def move_and_apply(state: pd.DataFrame, direction: List[str], statements: bool):
    # tuple = (index of row with 0, index of 0 in the row)
    # zero index = zero_position[1]
    # zero_row_index = zero_position[0]
    zero_position = find_zero(state)
    succesor_states = []
    if statements:
        print('Starting state: \n', state)
        print()
        print('The applicable moves are: ', direction)
        print()
    for dir in direction: 

        if dir == "Right":
            new_state = copy_state(state) 
            new_zero_row = zero_position[0]
            new_zero_index = zero_position[1] + 1
            new_state = swap(new_state, zero_position, (new_zero_row, new_zero_index))
            succesor_states.append(new_state['start'].tolist())
            if(statements):
                print("Successor state after 'right'\n", new_state)
                print('\n')
        if dir == "Left":
            new_state = copy_state(state) 
            new_zero_row = zero_position[0]
            new_zero_index = zero_position[1] - 1
            new_state = swap(new_state, zero_position, (new_zero_row, new_zero_index))
            succesor_states.append(new_state['start'].tolist())
            if(statements):
                print("Successor state after 'left'\n", new_state)
                print()
        if dir == "Up":
            new_state = copy_state(state) 
            new_zero_row = zero_position[0]-1 
            new_zero_index = zero_position[1]
            new_state = swap(new_state, zero_position, (new_zero_row, new_zero_index))
            succesor_states.append(new_state['start'].tolist())
            if(statements):
                print("Successor state after 'up'\n", new_state)
                print()
        if dir == "Down":
            new_state = copy_state(state) 
            new_zero_row = zero_position[0]+1 
            new_zero_index = zero_position[1]
            new_state = swap(new_state, zero_position, (new_zero_row, new_zero_index))
            succesor_states.append(new_state['start'].tolist())
            if(statements):
                print("Successor state after 'down'\n", new_state)
                print()
    return succesor_states

def succesor_state(states:List):
    print(states)

# %%
applicable_moves(df1)
# Out:
# ['Right', 'Up', 'Down']

# %%
applicable_moves(testdf)
# Out:
# ['Right', 'Left', 'Up', 'Down']

# %%
result1 = move_and_apply(df1,applicable_moves(df1),True)
# Out:
# Starting state:
#     n      start       goal
# 0  3  [3, 1, 2]  [0, 1, 2]
# 1  3  [0, 4, 5]  [3, 4, 5]
# 2  3  [6, 7, 8]  [6, 7, 8]
#
# The applicable moves are:  ['Right', 'Up', 'Down']
#
# Successor state after 'right'
#         start
# 0  [3, 1, 2]
# 1  [4, 0, 5]
# 2  [6, 7, 8]
#
#
# Successor state after 'up'
#         start
# 0  [0, 1, 2]
# 1  [3, 4, 5]
# 2  [6, 7, 8]
#
# Successor state after 'down'
#         start
# 0  [3, 1, 2]
# 1  [6, 4, 5]
# 2  [0, 7, 8]

# %%
test_result = move_and_apply(testdf,applicable_moves(testdf),True)
# Out:
# Starting state:
#     n      start       goal
# 0  3  [7, 2, 4]  [0, 1, 2]
# 1  3  [5, 0, 6]  [3, 4, 5]
# 2  3  [8, 3, 1]  [6, 7, 8]
#
# The applicable moves are:  ['Right', 'Left', 'Up', 'Down']
#
# Successor state after 'right'
#         start
# 0  [7, 2, 4]
# 1  [5, 6, 0]
# 2  [8, 3, 1]
#
#
# Successor state after 'left'
#         start
# 0  [7, 2, 4]
# 1  [0, 5, 6]
# 2  [8, 3, 1]
#
# Successor state after 'up'
#         start
# 0  [7, 0, 4]
# 1  [5, 2, 6]
# 2  [8, 3, 1]
#
# Successor state after 'down'
#         start
# 0  [7, 2, 4]
# 1  [5, 3, 6]
# 2  [8, 0, 1]

# %%
succesor_state(result1)
# Out:
# [[[3, 1, 2], [4, 0, 5], [6, 7, 8]], [[0, 1, 2], [3, 4, 5], [6, 7, 8]], [[3, 1, 2], [6, 4, 5], [0, 7, 8]]]

# %%
succesor_state(test_result)
# Out:
# [[[7, 2, 4], [5, 6, 0], [8, 3, 1]], [[7, 2, 4], [0, 5, 6], [8, 3, 1]], [[7, 0, 4], [5, 2, 6], [8, 3, 1]], [[7, 2, 4], [5, 3, 6], [8, 0, 1]]]

# %% [markdown]
# ### Part 3
# - The DATALIST argument is a list of the states in the current search path.
# - The algorithm returns either a list of the rules to reach the goal state or failure if no goal was found. [You will have to decide how to represent failure in your implementation. Note that returning an empty list for failure is not a good idea because an empty list represents success when you are at the goal.]
# - Implement the BACKTRACK1(DATALIST) algorithm to solve instances of the sliding-puzzle problem. The depth bound may be a global variable or passed as an argument
# - Implement a main program to accept a sliding-tile puzzle problem and solve it using the BACKTRACK1(DATALIST) algorithm. Print the **start state** and the **goal state**, the **solution** and **solution length**, and the **number of states that were examined**
# - Implement a main program to accept a sliding-tile puzzle problem and solve it using an *iterative depth- first search* using the BACKTRACK1(DATALIST) algorithm. Print the **cumulative number of states** examined and the **final (optimal) solution**.

# %%
from collections import deque

def DFS(state: pd.DataFrame, goal):
    # convert state into list form
    list_state = state['start'].tolist()
    stack = deque([(list_state, 0, [])]) 

    # print out start and goal states
    print("start:")
    for row in list_state:
        print(" ".join(map(str, row)))
    print()
    print("goal:")
    for row in goal:
        print(" ".join(map(str, row)))
    print()

    # explored will contain all the states that have been visited
    explored = set()
    # total number of nodes/states generated
    total_nodes_generated = 0
    cumulative_nodes = 0

    while stack:
        current_state, depth, path = stack.pop()  
        total_nodes_generated += 1
        
        if current_state == goal:
            print(f"Solution length = {depth}")
            print(f"Nodes generated = {total_nodes_generated}")
            print("Nodes examined:", cumulative_nodes)
            print("(list")
            
            # Print each move in the solution path
            for move in path:
                print(f"(rule '{move}')")
            print(")")
            return

        # Mark current state as explored
        explored.add(tuple(map(tuple, current_state)))

        # Convert current_state back to DataFrame to use in move_and_apply and applicable_moves
        df = pd.DataFrame({'start': current_state})

        # Get the applicable moves and apply them
        result = move_and_apply(df, applicable_moves(df), False)
        cumulative_nodes += len(explored)

        # For each resulting state, push it to the stack with the move that generated it
        moves = applicable_moves(df)
        for i, descendant in enumerate(result):
            # Convert lists to tuples
            descendant_tuple = tuple(map(tuple, descendant)) 
            if descendant_tuple not in explored and descendant not in stack:
                # Append the move to the path
                new_path = path + [moves[i]]  
                # Add new state, depth, and path
                stack.append((descendant, depth + 1, new_path))

# %%
goal = [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

DFS(df1,goal)
# Out:
# start:
# 3 1 2
# 0 4 5
# 6 7 8
#
# goal:
# 0 1 2
# 3 4 5
# 6 7 8
#
# Solution length = 29
# Nodes generated = 30
# Nodes examined: 435
# (list
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# )

# %%
test_state = [[7, 2, 4],[5, 0, 6],[8, 3, 1]]
testdf = pd.DataFrame({'start': test_state})
DFS(testdf,goal)
# Out:
# start:
# 7 2 4
# 5 0 6
# 8 3 1
#
# goal:
# 0 1 2
# 3 4 5
# 6 7 8
#
# Solution length = 112716
# Nodes generated = 127024
# Nodes examined: 8067456402
# (list
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# ...
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Right')
# (rule 'Up')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# (rule 'Right')
# (rule 'Down')
# (rule 'Down')
# (rule 'Left')
# (rule 'Up')
# (rule 'Up')
# )

# %%
def DFS_backtrack_iterative(state: pd.DataFrame, goal):
    # Convert initial state into a list for easier manipulation
    list_state = state['start'].tolist()

     # print out start and goal states
    print("start:")
    for row in list_state:
        print(" ".join(map(str, row)))
    print()
    print("goal:")
    for row in goal:
        print(" ".join(map(str, row)))
    print()
    
    # Set to track explored states and a stack to simulate DFS
    explored = set()  # Set to track explored states for fast lookup
    stack = deque([(list_state, 0, [])])  # Stack stores (current_state, depth, path)
    number_of_nodes = 0  # To count the number of states examined
    cumulative_index = 0
    cumulative_nodes = 0

    while stack:
        # Pop the current state, depth, and path from the stack
        current_state, depth, path = stack.pop()

        # Increment the number of examined states
        number_of_nodes += 1
        current_state_tuple = tuple(map(tuple, current_state))  # Convert to tuple for hashing
        
        # If the current state matches the goal state, print the solution details and exit
        if current_state == goal:
            print("Solution found!")
            print("Final (optimal) solution path:", path + [current_state])
            print("Solution length (depth):", depth)
            return

        # Mark the current state as explored
        explored.add(current_state_tuple)

        # Generate possible states from the current state
        df = pd.DataFrame({'start': current_state})
        possible_states = move_and_apply(df, applicable_moves(df), False)
        
        cumulative_nodes += len(explored)
        cumulative_index += 1
        print(f"{cumulative_index}: Cumulative number of states examined = ", cumulative_nodes)
        
        # Iterate through each possible next state
        for next_state in possible_states:
            next_state_tuple = tuple(map(tuple, next_state))

            # Only add the state to the stack if it hasn't been explored
            if next_state_tuple not in explored:
                stack.append((next_state, depth + 1, path + [current_state]))

    # If no solution is found, print the number of states examined
    print("No solution found.")
    print("Cumulative number of states examined:", cumulative_nodes)

# %%
DFS_backtrack_iterative(df1,goal)
# Out:
# start:
# 3 1 2
# 0 4 5
# 6 7 8
#
# goal:
# 0 1 2
# 3 4 5
# 6 7 8
#
# 1: Cumulative number of states examined =  1
# 2: Cumulative number of states examined =  3
# 3: Cumulative number of states examined =  6
# 4: Cumulative number of states examined =  10
# 5: Cumulative number of states examined =  15
# 6: Cumulative number of states examined =  21
# 7: Cumulative number of states examined =  28
# 8: Cumulative number of states examined =  36
# 9: Cumulative number of states examined =  45
# 10: Cumulative number of states examined =  55
# 11: Cumulative number of states examined =  66
# 12: Cumulative number of states examined =  78
# 13: Cumulative number of states examined =  91
# 14: Cumulative number of states examined =  105
# 15: Cumulative number of states examined =  120
# 16: Cumulative number of states examined =  136
# 17: Cumulative number of states examined =  153
# 18: Cumulative number of states examined =  171
# 19: Cumulative number of states examined =  190
# 20: Cumulative number of states examined =  210
# 21: Cumulative number of states examined =  231
# 22: Cumulative number of states examined =  253
# 23: Cumulative number of states examined =  276
# 24: Cumulative number of states examined =  300
# 25: Cumulative number of states examined =  325
# 26: Cumulative number of states examined =  351
# 27: Cumulative number of states examined =  378
# 28: Cumulative number of states examined =  406
# 29: Cumulative number of states examined =  435
# Solution found!
# Final (optimal) solution path: [[[3, 1, 2], [0, 4, 5], [6, 7, 8]], [[3, 1, 2], [6, 4, 5], [0, 7, 8]], [[3, 1, 2], [6, 4, 5], [7, 0, 8]], [[3, 1, 2], [6, 0, 5], [7, 4, 8]], [[3, 0, 2], [6, 1, 5], [7, 4, 8]], [[0, 3, 2], [6, 1, 5], [7, 4, 8]], [[6, 3, 2], [0, 1, 5], [7, 4, 8]], [[6, 3, 2], [7, 1, 5], [0, 4, 8]], [[6, 3, 2], [7, 1, 5], [4, 0, 8]], [[6, 3, 2], [7, 0, 5], [4, 1, 8]], [[6, 0, 2], [7, 3, 5], [4, 1, 8]], [[0, 6, 2], [7, 3, 5], [4, 1, 8]], [[7, 6, 2], [0, 3, 5], [4, 1, 8]], [[7, 6, 2], [4, 3, 5], [0, 1, 8]], [[7, 6, 2], [4, 3, 5], [1, 0, 8]], [[7, 6, 2], [4, 0, 5], [1, 3, 8]], [[7, 0, 2], [4, 6, 5], [1, 3, 8]], [[0, 7, 2], [4, 6, 5], [1, 3, 8]], [[4, 7, 2], [0, 6, 5], [1, 3, 8]], [[4, 7, 2], [1, 6, 5], [0, 3, 8]], [[4, 7, 2], [1, 6, 5], [3, 0, 8]], [[4, 7, 2], [1, 0, 5], [3, 6, 8]], [[4, 0, 2], [1, 7, 5], [3, 6, 8]], [[0, 4, 2], [1, 7, 5], [3, 6, 8]], [[1, 4, 2], [0, 7, 5], [3, 6, 8]], [[1, 4, 2], [3, 7, 5], [0, 6, 8]], [[1, 4, 2], [3, 7, 5], [6, 0, 8]], [[1, 4, 2], [3, 0, 5], [6, 7, 8]], [[1, 0, 2], [3, 4, 5], [6, 7, 8]], [[0, 1, 2], [3, 4, 5], [6, 7, 8]]]
# Solution length (depth): 29

# %%
test_state = [[7, 2, 4],[5, 0, 6],[8, 3, 1]]
testdf = pd.DataFrame({'start': test_state})
DFS_backtrack_iterative(testdf,goal)
# Out:
# start:
# 7 2 4
# 5 0 6
# 8 3 1
#
# goal:
# 0 1 2
# 3 4 5
# 6 7 8
#
# 1: Cumulative number of states examined =  1
# 2: Cumulative number of states examined =  3
# 3: Cumulative number of states examined =  6
# 4: Cumulative number of states examined =  10
# 5: Cumulative number of states examined =  15
# 6: Cumulative number of states examined =  21
# 7: Cumulative number of states examined =  28
# 8: Cumulative number of states examined =  36
# 9: Cumulative number of states examined =  45
# 10: Cumulative number of states examined =  55
# 11: Cumulative number of states examined =  66
# 12: Cumulative number of states examined =  78
# 13: Cumulative number of states examined =  91
# 14: Cumulative number of states examined =  105
# 15: Cumulative number of states examined =  120
# 16: Cumulative number of states examined =  136
# 17: Cumulative number of states examined =  153
# 18: Cumulative number of states examined =  171
# 19: Cumulative number of states examined =  190
# 20: Cumulative number of states examined =  210
# 21: Cumulative number of states examined =  231
# 22: Cumulative number of states examined =  253
# 23: Cumulative number of states examined =  276
# 24: Cumulative number of states examined =  300
# 25: Cumulative number of states examined =  325
# 26: Cumulative number of states examined =  351
# 27: Cumulative number of states examined =  378
# 28: Cumulative number of states examined =  406
# 29: Cumulative number of states examined =  435
# 30: Cumulative number of states examined =  465
# 31: Cumulative number of states examined =  496
# 32: Cumulative number of states examined =  528
# 33: Cumulative number of states examined =  561
# 34: Cumulative number of states examined =  595
# 35: Cumulative number of states examined =  630
# 36: Cumulative number of states examined =  666
# 37: Cumulative number of states examined =  703
# 38: Cumulative number of states examined =  741
# 39: Cumulative number of states examined =  780
# 40: Cumulative number of states examined =  820
# 41: Cumulative number of states examined =  861
# 42: Cumulative number of states examined =  903
# 43: Cumulative number of states examined =  946
# 44: Cumulative number of states examined =  990
# 45: Cumulative number of states examined =  1035
# 46: Cumulative number of states examined =  1081
# 47: Cumulative number of states examined =  1128
# 48: Cumulative number of states examined =  1176
# 49: Cumulative number of states examined =  1225
# 50: Cumulative number of states examined =  1275
# 51: Cumulative number of states examined =  1326
# 52: Cumulative number of states examined =  1378
# 53: Cumulative number of states examined =  1431
# 54: Cumulative number of states examined =  1485
# 55: Cumulative number of states examined =  1540
# 56: Cumulative number of states examined =  1596
# 57: Cumulative number of states examined =  1653
# 58: Cumulative number of states examined =  1711
# 59: Cumulative number of states examined =  1770
# 60: Cumulative number of states examined =  1830
# 61: Cumulative number of states examined =  1891
# 62: Cumulative number of states examined =  1953
# 63: Cumulative number of states examined =  2016
# 64: Cumulative number of states examined =  2080
# 65: Cumulative number of states examined =  2145
# 66: Cumulative number of states examined =  2211
# 67: Cumulative number of states examined =  2278
# 68: Cumulative number of states examined =  2346
# 69: Cumulative number of states examined =  2415
# 70: Cumulative number of states examined =  2485
# 71: Cumulative number of states examined =  2556
# 72: Cumulative number of states examined =  2628
# 73: Cumulative number of states examined =  2701
# 74: Cumulative number of states examined =  2775
# 75: Cumulative number of states examined =  2850
# 76: Cumulative number of states examined =  2926
# 77: Cumulative number of states examined =  3003
# 78: Cumulative number of states examined =  3081
# 79: Cumulative number of states examined =  3160
# 80: Cumulative number of states examined =  3240
# 81: Cumulative number of states examined =  3321
# 82: Cumulative number of states examined =  3403
# 83: Cumulative number of states examined =  3486
# 84: Cumulative number of states examined =  3570
# 85: Cumulative number of states examined =  3655
# 86: Cumulative number of states examined =  3741
# 87: Cumulative number of states examined =  3828
# 88: Cumulative number of states examined =  3916
# 89: Cumulative number of states examined =  4005
# 90: Cumulative number of states examined =  4095
# 91: Cumulative number of states examined =  4186
# 92: Cumulative number of states examined =  4278
# 93: Cumulative number of states examined =  4371
# 94: Cumulative number of states examined =  4465
# 95: Cumulative number of states examined =  4560
# 96: Cumulative number of states examined =  4656
# 97: Cumulative number of states examined =  4753
# 98: Cumulative number of states examined =  4851
# 99: Cumulative number of states examined =  4950
# 100: Cumulative number of states examined =  5050
# 101: Cumulative number of states examined =  5151
# 102: Cumulative number of states examined =  5253
# 103: Cumulative number of states examined =  5356
# 104: Cumulative number of states examined =  5460
# 105: Cumulative number of states examined =  5565
# 106: Cumulative number of states examined =  5671
# 107: Cumulative number of states examined =  5778
# 108: Cumulative number of states examined =  5886
# 109: Cumulative number of states examined =  5995
# 110: Cumulative number of states examined =  6105
# 111: Cumulative number of states examined =  6216
# 112: Cumulative number of states examined =  6328
# 113: Cumulative number of states examined =  6441
# 114: Cumulative number of states examined =  6555
# 115: Cumulative number of states examined =  6670
# 116: Cumulative number of states examined =  6786
# 117: Cumulative number of states examined =  6903
# 118: Cumulative number of states examined =  7021
# 119: Cumulative number of states examined =  7140
# 120: Cumulative number of states examined =  7260
# 121: Cumulative number of states examined =  7381
# 122: Cumulative number of states examined =  7503
# 123: Cumulative number of states examined =  7626
# 124: Cumulative number of states examined =  7750
# 125: Cumulative number of states examined =  7875
# 126: Cumulative number of states examined =  8001
# 127: Cumulative number of states examined =  8128
# 128: Cumulative number of states examined =  8256
# 129: Cumulative number of states examined =  8385
# 130: Cumulative number of states examined =  8515
# 131: Cumulative number of states examined =  8646
# 132: Cumulative number of states examined =  8778
# 133: Cumulative number of states examined =  8911
# 134: Cumulative number of states examined =  9045
# 135: Cumulative number of states examined =  9180
# 136: Cumulative number of states examined =  9316
# 137: Cumulative number of states examined =  9453
# 138: Cumulative number of states examined =  9591
# 139: Cumulative number of states examined =  9730
# 140: Cumulative number of states examined =  9870
# 141: Cumulative number of states examined =  10011
# 142: Cumulative number of states examined =  10153
# 143: Cumulative number of states examined =  10296
# 144: Cumulative number of states examined =  10440
# 145: Cumulative number of states examined =  10585
# 146: Cumulative number of states examined =  10731
# 147: Cumulative number of states examined =  10878
# 148: Cumulative number of states examined =  11026
# 149: Cumulative number of states examined =  11175
# 150: Cumulative number of states examined =  11325
# 151: Cumulative number of states examined =  11476
# 152: Cumulative number of states examined =  11628
# 153: Cumulative number of states examined =  11781
# 154: Cumulative number of states examined =  11935
# 155: Cumulative number of states examined =  12090
# 156: Cumulative number of states examined =  12246
# 157: Cumulative number of states examined =  12403
# 158: Cumulative number of states examined =  12561
# 159: Cumulative number of states examined =  12720
# 160: Cumulative number of states examined =  12880
# 161: Cumulative number of states examined =  13041
# 162: Cumulative number of states examined =  13203
# 163: Cumulative number of states examined =  13366
# 164: Cumulative number of states examined =  13530
# 165: Cumulative number of states examined =  13695
# 166: Cumulative number of states examined =  13861
# 167: Cumulative number of states examined =  14028
# 168: Cumulative number of states examined =  14196
# 169: Cumulative number of states examined =  14365
# 170: Cumulative number of states examined =  14535
# 171: Cumulative number of states examined =  14706
# 172: Cumulative number of states examined =  14878
# 173: Cumulative number of states examined =  15051
# 174: Cumulative number of states examined =  15225
# 175: Cumulative number of states examined =  15400
# 176: Cumulative number of states examined =  15576
# 177: Cumulative number of states examined =  15753
# 178: Cumulative number of states examined =  15931
# 179: Cumulative number of states examined =  16110
# 180: Cumulative number of states examined =  16290
# 181: Cumulative number of states examined =  16471
# 182: Cumulative number of states examined =  16653
# 183: Cumulative number of states examined =  16836
# 184: Cumulative number of states examined =  17020
# 185: Cumulative number of states examined =  17205
# 186: Cumulative number of states examined =  17391
# 187: Cumulative number of states examined =  17578
# 188: Cumulative number of states examined =  17766
# 189: Cumulative number of states examined =  17955
# 190: Cumulative number of states examined =  18145
# 191: Cumulative number of states examined =  18336
# 192: Cumulative number of states examined =  18528
# 193: Cumulative number of states examined =  18721
# 194: Cumulative number of states examined =  18915
# 195: Cumulative number of states examined =  19110
# 196: Cumulative number of states examined =  19306
# 197: Cumulative number of states examined =  19503
# 198: Cumulative number of states examined =  19701
# 199: Cumulative number of states examined =  19900
# 200: Cumulative number of states examined =  20100
# 201: Cumulative number of states examined =  20301
# 202: Cumulative number of states examined =  20503
# 203: Cumulative number of states examined =  20706
# 204: Cumulative number of states examined =  20910
# 205: Cumulative number of states examined =  21115
# 206: Cumulative number of states examined =  21321
# 207: Cumulative number of states examined =  21528
# 208: Cumulative number of states examined =  21736
# 209: Cumulative number of states examined =  21945
# 210: Cumulative number of states examined =  22155
# 211: Cumulative number of states examined =  22366
# 212: Cumulative number of states examined =  22578
# 213: Cumulative number of states examined =  22791
# 214: Cumulative number of states examined =  23005
# 215: Cumulative number of states examined =  23220
# 216: Cumulative number of states examined =  23436
# 217: Cumulative number of states examined =  23653
# 218: Cumulative number of states examined =  23871
# 219: Cumulative number of states examined =  24090
# 220: Cumulative number of states examined =  24310
# 221: Cumulative number of states examined =  24531
# 222: Cumulative number of states examined =  24753
# 223: Cumulative number of states examined =  24976
# 224: Cumulative number of states examined =  25200
# 225: Cumulative number of states examined =  25425
# 226: Cumulative number of states examined =  25651
# 227: Cumulative number of states examined =  25878
# 228: Cumulative number of states examined =  26106
# 229: Cumulative number of states examined =  26335
# 230: Cumulative number of states examined =  26565
# 231: Cumulative number of states examined =  26796
# 232: Cumulative number of states examined =  27028
# 233: Cumulative number of states examined =  27261
# 234: Cumulative number of states examined =  27495
# 235: Cumulative number of states examined =  27730
# 236: Cumulative number of states examined =  27966
# 237: Cumulative number of states examined =  28203
# 238: Cumulative number of states examined =  28441
# 239: Cumulative number of states examined =  28680
# 240: Cumulative number of states examined =  28920
# 241: Cumulative number of states examined =  29161
# 242: Cumulative number of states examined =  29403
# 243: Cumulative number of states examined =  29646
# 244: Cumulative number of states examined =  29890
# 245: Cumulative number of states examined =  30135
# 246: Cumulative number of states examined =  30381
# 247: Cumulative number of states examined =  30628
# 248: Cumulative number of states examined =  30876
# 249: Cumulative number of states examined =  31125
# 250: Cumulative number of states examined =  31375
# 251: Cumulative number of states examined =  31626
# 252: Cumulative number of states examined =  31878
# 253: Cumulative number of states examined =  32131
# 254: Cumulative number of states examined =  32385
# 255: Cumulative number of states examined =  32640
# 256: Cumulative number of states examined =  32896
# 257: Cumulative number of states examined =  33153
# 258: Cumulative number of states examined =  33411
# 259: Cumulative number of states examined =  33670
# 260: Cumulative number of states examined =  33930
# 261: Cumulative number of states examined =  34191
# 262: Cumulative number of states examined =  34453
# 263: Cumulative number of states examined =  34716
# 264: Cumulative number of states examined =  34980
# 265: Cumulative number of states examined =  35245
# 266: Cumulative number of states examined =  35511
# 267: Cumulative number of states examined =  35778
# 268: Cumulative number of states examined =  36046
# 269: Cumulative number of states examined =  36315
# 270: Cumulative number of states examined =  36585
# 271: Cumulative number of states examined =  36856
# 272: Cumulative number of states examined =  37128
# 273: Cumulative number of states examined =  37401
# 274: Cumulative number of states examined =  37675
# 275: Cumulative number of states examined =  37950
# 276: Cumulative number of states examined =  38226
# 277: Cumulative number of states examined =  38503
# 278: Cumulative number of states examined =  38781
# 279: Cumulative number of states examined =  39060
# 280: Cumulative number of states examined =  39340
# 281: Cumulative number of states examined =  39621
# 282: Cumulative number of states examined =  39903
# 283: Cumulative number of states examined =  40186
# 284: Cumulative number of states examined =  40470
# 285: Cumulative number of states examined =  40755
# 286: Cumulative number of states examined =  41041
# 287: Cumulative number of states examined =  41328
# 288: Cumulative number of states examined =  41616
# 289: Cumulative number of states examined =  41905
# 290: Cumulative number of states examined =  42195
# 291: Cumulative number of states examined =  42486
# 292: Cumulative number of states examined =  42778
# 293: Cumulative number of states examined =  43071
# 294: Cumulative number of states examined =  43365
# 295: Cumulative number of states examined =  43660
# 296: Cumulative number of states examined =  43956
# 297: Cumulative number of states examined =  44253
# 298: Cumulative number of states examined =  44551
# 299: Cumulative number of states examined =  44850
# 300: Cumulative number of states examined =  45150
# 301: Cumulative number of states examined =  45451
# 302: Cumulative number of states examined =  45753
# 303: Cumulative number of states examined =  46056
# 304: Cumulative number of states examined =  46360
# 305: Cumulative number of states examined =  46665
# 306: Cumulative number of states examined =  46971
# 307: Cumulative number of states examined =  47278
# 308: Cumulative number of states examined =  47586
# 309: Cumulative number of states examined =  47895
# 310: Cumulative number of states examined =  48205
# 311: Cumulative number of states examined =  48516
# 312: Cumulative number of states examined =  48828
# 313: Cumulative number of states examined =  49141
# 314: Cumulative number of states examined =  49455
# 315: Cumulative number of states examined =  49770
# 316: Cumulative number of states examined =  50086
# 317: Cumulative number of states examined =  50403
# 318: Cumulative number of states examined =  50721
# 319: Cumulative number of states examined =  51040
# 320: Cumulative number of states examined =  51360
# 321: Cumulative number of states examined =  51681
# 322: Cumulative number of states examined =  52003
# 323: Cumulative number of states examined =  52326
# 324: Cumulative number of states examined =  52650
# 325: Cumulative number of states examined =  52975
# 326: Cumulative number of states examined =  53301
# 327: Cumulative number of states examined =  53628
# 328: Cumulative number of states examined =  53956
# 329: Cumulative number of states examined =  54285
# 330: Cumulative number of states examined =  54615
# 331: Cumulative number of states examined =  54946
# 332: Cumulative number of states examined =  55278
# 333: Cumulative number of states examined =  55611
# 334: Cumulative number of states examined =  55945
# 335: Cumulative number of states examined =  56280
# 336: Cumulative number of states examined =  56616
# 337: Cumulative number of states examined =  56953
# 338: Cumulative number of states examined =  57291
# 339: Cumulative number of states examined =  57630
# 340: Cumulative number of states examined =  57970
# 341: Cumulative number of states examined =  58311
# 342: Cumulative number of states examined =  58653
# 343: Cumulative number of states examined =  58996
# 344: Cumulative number of states examined =  59340
# 345: Cumulative number of states examined =  59685
# 346: Cumulative number of states examined =  60031
# 347: Cumulative number of states examined =  60378
# 348: Cumulative number of states examined =  60726
# 349: Cumulative number of states examined =  61075
# 350: Cumulative number of states examined =  61425
# 351: Cumulative number of states examined =  61776
# 352: Cumulative number of states examined =  62128
# 353: Cumulative number of states examined =  62481
# 354: Cumulative number of states examined =  62835
# 355: Cumulative number of states examined =  63190
# 356: Cumulative number of states examined =  63546
# 357: Cumulative number of states examined =  63903
# 358: Cumulative number of states examined =  64261
# 359: Cumulative number of states examined =  64620
# 360: Cumulative number of states examined =  64980
# 361: Cumulative number of states examined =  65341
# 362: Cumulative number of states examined =  65703
# 363: Cumulative number of states examined =  66066
# 364: Cumulative number of states examined =  66430
# 365: Cumulative number of states examined =  66795
# 366: Cumulative number of states examined =  67161
# 367: Cumulative number of states examined =  67528
# 368: Cumulative number of states examined =  67896
# 369: Cumulative number of states examined =  68265
# 370: Cumulative number of states examined =  68635
# 371: Cumulative number of states examined =  69006
# 372: Cumulative number of states examined =  69378
# 373: Cumulative number of states examined =  69751
# 374: Cumulative number of states examined =  70125
# 375: Cumulative number of states examined =  70500
# 376: Cumulative number of states examined =  70876
# 377: Cumulative number of states examined =  71253
# 378: Cumulative number of states examined =  71631
# 379: Cumulative number of states examined =  72010
# 380: Cumulative number of states examined =  72390
# 381: Cumulative number of states examined =  72771
# 382: Cumulative number of states examined =  73153
# 383: Cumulative number of states examined =  73536
# 384: Cumulative number of states examined =  73920
# 385: Cumulative number of states examined =  74305
# 386: Cumulative number of states examined =  74691
# 387: Cumulative number of states examined =  75078
# 388: Cumulative number of states examined =  75466
# 389: Cumulative number of states examined =  75855
# 390: Cumulative number of states examined =  76245
# 391: Cumulative number of states examined =  76636
# 392: Cumulative number of states examined =  77028
# 393: Cumulative number of states examined =  77421
# 394: Cumulative number of states examined =  77815
# 395: Cumulative number of states examined =  78210
# 396: Cumulative number of states examined =  78606
# 397: Cumulative number of states examined =  79003
# 398: Cumulative number of states examined =  79401
# 399: Cumulative number of states examined =  79800
# 400: Cumulative number of states examined =  80200
# 401: Cumulative number of states examined =  80601
# 402: Cumulative number of states examined =  81003
# 403: Cumulative number of states examined =  81406
# 404: Cumulative number of states examined =  81810
# 405: Cumulative number of states examined =  82215
# 406: Cumulative number of states examined =  82621
# 407: Cumulative number of states examined =  83028
# 408: Cumulative number of states examined =  83436
# 409: Cumulative number of states examined =  83845
# 410: Cumulative number of states examined =  84255
# 411: Cumulative number of states examined =  84666
# 412: Cumulative number of states examined =  85078
# 413: Cumulative number of states examined =  85491
# 414: Cumulative number of states examined =  85905
# 415: Cumulative number of states examined =  86320
# 416: Cumulative number of states examined =  86736
# 417: Cumulative number of states examined =  87153
# 418: Cumulative number of states examined =  87571
# 419: Cumulative number of states examined =  87990
# 420: Cumulative number of states examined =  88410
# 421: Cumulative number of states examined =  88831
# 422: Cumulative number of states examined =  89253
# 423: Cumulative number of states examined =  89676
# 424: Cumulative number of states examined =  90100
# 425: Cumulative number of states examined =  90525
# 426: Cumulative number of states examined =  90951
# 427: Cumulative number of states examined =  91378
# 428: Cumulative number of states examined =  91806
# 429: Cumulative number of states examined =  92235
# 430: Cumulative number of states examined =  92665
# 431: Cumulative number of states examined =  93096
# 432: Cumulative number of states examined =  93528
# 433: Cumulative number of states examined =  93961
# 434: Cumulative number of states examined =  94395
# 435: Cumulative number of states examined =  94830
# 436: Cumulative number of states examined =  95266
# 437: Cumulative number of states examined =  95703
# 438: Cumulative number of states examined =  96141
# 439: Cumulative number of states examined =  96580
# 440: Cumulative number of states examined =  97020
# 441: Cumulative number of states examined =  97461
# 442: Cumulative number of states examined =  97903
# 443: Cumulative number of states examined =  98346
# 444: Cumulative number of states examined =  98790
# 445: Cumulative number of states examined =  99235
# 446: Cumulative number of states examined =  99681
# 447: Cumulative number of states examined =  100128
# 448: Cumulative number of states examined =  100576
# 449: Cumulative number of states examined =  101025
# 450: Cumulative number of states examined =  101475
# 451: Cumulative number of states examined =  101926
# 452: Cumulative number of states examined =  102378
# 453: Cumulative number of states examined =  102831
# 454: Cumulative number of states examined =  103285
# 455: Cumulative number of states examined =  103740
# 456: Cumulative number of states examined =  104196
# 457: Cumulative number of states examined =  104653
# 458: Cumulative number of states examined =  105111
# 459: Cumulative number of states examined =  105570
# 460: Cumulative number of states examined =  106030
# 461: Cumulative number of states examined =  106491
# 462: Cumulative number of states examined =  106953
# 463: Cumulative number of states examined =  107416
# 464: Cumulative number of states examined =  107880
# 465: Cumulative number of states examined =  108345
# 466: Cumulative number of states examined =  108811
# 467: Cumulative number of states examined =  109278
# 468: Cumulative number of states examined =  109746
# 469: Cumulative number of states examined =  110215
# 470: Cumulative number of states examined =  110685
# 471: Cumulative number of states examined =  111156
# 472: Cumulative number of states examined =  111628
# 473: Cumulative number of states examined =  112101
# 474: Cumulative number of states examined =  112575
# 475: Cumulative number of states examined =  113050
# 476: Cumulative number of states examined =  113526
# 477: Cumulative number of states examined =  114003
# 478: Cumulative number of states examined =  114481
# 479: Cumulative number of states examined =  114960
# 480: Cumulative number of states examined =  115440
# 481: Cumulative number of states examined =  115921
# 482: Cumulative number of states examined =  116403
# 483: Cumulative number of states examined =  116886
# 484: Cumulative number of states examined =  117370
# 485: Cumulative number of states examined =  117855
# 486: Cumulative number of states examined =  118341
# 487: Cumulative number of states examined =  118828
# 488: Cumulative number of states examined =  119316
# 489: Cumulative number of states examined =  119805
# 490: Cumulative number of states examined =  120295
# 491: Cumulative number of states examined =  120786
# 492: Cumulative number of states examined =  121278
# 493: Cumulative number of states examined =  121771
# 494: Cumulative number of states examined =  122265
# 495: Cumulative number of states examined =  122760
# 496: Cumulative number of states examined =  123256
# 497: Cumulative number of states examined =  123753
# 498: Cumulative number of states examined =  124251
# 499: Cumulative number of states examined =  124750
# 500: Cumulative number of states examined =  125250
# 501: Cumulative number of states examined =  125751
# 502: Cumulative number of states examined =  126253
# 503: Cumulative number of states examined =  126756
# 504: Cumulative number of states examined =  127260
# 505: Cumulative number of states examined =  127765
# 506: Cumulative number of states examined =  128271
# 507: Cumulative number of states examined =  128778
# 508: Cumulative number of states examined =  129286
# 509: Cumulative number of states examined =  129795
# 510: Cumulative number of states examined =  130305
# 511: Cumulative number of states examined =  130816
# 512: Cumulative number of states examined =  131328
# 513: Cumulative number of states examined =  131841
# 514: Cumulative number of states examined =  132355
# 515: Cumulative number of states examined =  132870
# 516: Cumulative number of states examined =  133386
# 517: Cumulative number of states examined =  133903
# 518: Cumulative number of states examined =  134421
# 519: Cumulative number of states examined =  134940
# 520: Cumulative number of states examined =  135460
# 521: Cumulative number of states examined =  135981
# 522: Cumulative number of states examined =  136503
# 523: Cumulative number of states examined =  137026
# 524: Cumulative number of states examined =  137550
# 525: Cumulative number of states examined =  138075
# 526: Cumulative number of states examined =  138601
# 527: Cumulative number of states examined =  139128
# 528: Cumulative number of states examined =  139656
# 529: Cumulative number of states examined =  140185
# 530: Cumulative number of states examined =  140715
# 531: Cumulative number of states examined =  141246
# 532: Cumulative number of states examined =  141778
# 533: Cumulative number of states examined =  142311
# 534: Cumulative number of states examined =  142845
# 535: Cumulative number of states examined =  143380
# 536: Cumulative number of states examined =  143916
# 537: Cumulative number of states examined =  144453
# 538: Cumulative number of states examined =  144991
# 539: Cumulative number of states examined =  145530
# 540: Cumulative number of states examined =  146070
# 541: Cumulative number of states examined =  146611
# 542: Cumulative number of states examined =  147153
# 543: Cumulative number of states examined =  147696
# 544: Cumulative number of states examined =  148240
# 545: Cumulative number of states examined =  148785
# 546: Cumulative number of states examined =  149331
# 547: Cumulative number of states examined =  149878
# 548: Cumulative number of states examined =  150426
# 549: Cumulative number of states examined =  150975
# 550: Cumulative number of states examined =  151525
# 551: Cumulative number of states examined =  152076
# 552: Cumulative number of states examined =  152628
# 553: Cumulative number of states examined =  153181
# 554: Cumulative number of states examined =  153735
# 555: Cumulative number of states examined =  154290
# 556: Cumulative number of states examined =  154846
# 557: Cumulative number of states examined =  155403
# 558: Cumulative number of states examined =  155961
# 559: Cumulative number of states examined =  156520
# 560: Cumulative number of states examined =  157080
# 561: Cumulative number of states examined =  157641
# 562: Cumulative number of states examined =  158203
# 563: Cumulative number of states examined =  158766
# 564: Cumulative number of states examined =  159330
# 565: Cumulative number of states examined =  159895
# 566: Cumulative number of states examined =  160461
# 567: Cumulative number of states examined =  161028
# 568: Cumulative number of states examined =  161596
# 569: Cumulative number of states examined =  162165
# 570: Cumulative number of states examined =  162735
# 571: Cumulative number of states examined =  163306
# 572: Cumulative number of states examined =  163878
# 573: Cumulative number of states examined =  164451
# 574: Cumulative number of states examined =  165025
# 575: Cumulative number of states examined =  165600
# 576: Cumulative number of states examined =  166176
# 577: Cumulative number of states examined =  166753
# 578: Cumulative number of states examined =  167331
# 579: Cumulative number of states examined =  167910
# 580: Cumulative number of states examined =  168490
# 581: Cumulative number of states examined =  169071
# 582: Cumulative number of states examined =  169653
# 583: Cumulative number of states examined =  170236
# 584: Cumulative number of states examined =  170820
# 585: Cumulative number of states examined =  171405
# 586: Cumulative number of states examined =  171991
# 587: Cumulative number of states examined =  172578
# 588: Cumulative number of states examined =  173166
# 589: Cumulative number of states examined =  173755
# 590: Cumulative number of states examined =  174345
# 591: Cumulative number of states examined =  174936
# 592: Cumulative number of states examined =  175528
# 593: Cumulative number of states examined =  176121
# 594: Cumulative number of states examined =  176715
# 595: Cumulative number of states examined =  177310
# 596: Cumulative number of states examined =  177906
# 597: Cumulative number of states examined =  178503
# 598: Cumulative number of states examined =  179101
# 599: Cumulative number of states examined =  179700
# 600: Cumulative number of states examined =  180300
# 601: Cumulative number of states examined =  180901
# 602: Cumulative number of states examined =  181503
# 603: Cumulative number of states examined =  182106
# 604: Cumulative number of states examined =  182710
# 605: Cumulative number of states examined =  183315
# 606: Cumulative number of states examined =  183921
# 607: Cumulative number of states examined =  184528
# 608: Cumulative number of states examined =  185136
# 609: Cumulative number of states examined =  185745
# 610: Cumulative number of states examined =  186355
# 611: Cumulative number of states examined =  186966
# 612: Cumulative number of states examined =  187578
# 613: Cumulative number of states examined =  188191
# 614: Cumulative number of states examined =  188805
# 615: Cumulative number of states examined =  189420
# 616: Cumulative number of states examined =  190036
# 617: Cumulative number of states examined =  190653
# 618: Cumulative number of states examined =  191271
# 619: Cumulative number of states examined =  191890
# 620: Cumulative number of states examined =  192510
# 621: Cumulative number of states examined =  193131
# 622: Cumulative number of states examined =  193753
# 623: Cumulative number of states examined =  194376
# 624: Cumulative number of states examined =  195000
# 625: Cumulative number of states examined =  195625
# 626: Cumulative number of states examined =  196251
# 627: Cumulative number of states examined =  196878
# 628: Cumulative number of states examined =  197506
# 629: Cumulative number of states examined =  198135
# 630: Cumulative number of states examined =  198765
# 631: Cumulative number of states examined =  199396
# 632: Cumulative number of states examined =  200028
# 633: Cumulative number of states examined =  200661
# 634: Cumulative number of states examined =  201295
# 635: Cumulative number of states examined =  201930
# 636: Cumulative number of states examined =  202566
# 637: Cumulative number of states examined =  203203
# 638: Cumulative number of states examined =  203841
# 639: Cumulative number of states examined =  204480
# 640: Cumulative number of states examined =  205120
# 641: Cumulative number of states examined =  205761
# 642: Cumulative number of states examined =  206403
# 643: Cumulative number of states examined =  207046
# 644: Cumulative number of states examined =  207690
# 645: Cumulative number of states examined =  208335
# 646: Cumulative number of states examined =  208981
# 647: Cumulative number of states examined =  209628
# 648: Cumulative number of states examined =  210276
# 649: Cumulative number of states examined =  210925
# 650: Cumulative number of states examined =  211575
# 651: Cumulative number of states examined =  212226
# 652: Cumulative number of states examined =  212878
# 653: Cumulative number of states examined =  213531
# 654: Cumulative number of states examined =  214185
# 655: Cumulative number of states examined =  214840
# 656: Cumulative number of states examined =  215496
# 657: Cumulative number of states examined =  216153
# 658: Cumulative number of states examined =  216811
# 659: Cumulative number of states examined =  217470
# 660: Cumulative number of states examined =  218130
# 661: Cumulative number of states examined =  218791
# 662: Cumulative number of states examined =  219453
# 663: Cumulative number of states examined =  220116
# 664: Cumulative number of states examined =  220780
# 665: Cumulative number of states examined =  221445
# 666: Cumulative number of states examined =  222111
# 667: Cumulative number of states examined =  222778
# 668: Cumulative number of states examined =  223446
# 669: Cumulative number of states examined =  224115
# 670: Cumulative number of states examined =  224785
# 671: Cumulative number of states examined =  225456
# 672: Cumulative number of states examined =  226128
# 673: Cumulative number of states examined =  226801
# 674: Cumulative number of states examined =  227475
# 675: Cumulative number of states examined =  228150
# 676: Cumulative number of states examined =  228826
# 677: Cumulative number of states examined =  229503
# 678: Cumulative number of states examined =  230181
# 679: Cumulative number of states examined =  230860
# 680: Cumulative number of states examined =  231540
# 681: Cumulative number of states examined =  232221
# 682: Cumulative number of states examined =  232903
# 683: Cumulative number of states examined =  233586
# 684: Cumulative number of states examined =  234270
# 685: Cumulative number of states examined =  234955
# 686: Cumulative number of states examined =  235641
# 687: Cumulative number of states examined =  236328
# 688: Cumulative number of states examined =  237016
# 689: Cumulative number of states examined =  237705
# 690: Cumulative number of states examined =  238395
# 691: Cumulative number of states examined =  239086
# 692: Cumulative number of states examined =  239778
# 693: Cumulative number of states examined =  240471
# 694: Cumulative number of states examined =  241165
# 695: Cumulative number of states examined =  241860
# 696: Cumulative number of states examined =  242556
# 697: Cumulative number of states examined =  243253
# 698: Cumulative number of states examined =  243951
# 699: Cumulative number of states examined =  244650
# 700: Cumulative number of states examined =  245350
# 701: Cumulative number of states examined =  246051
# 702: Cumulative number of states examined =  246753
# 703: Cumulative number of states examined =  247456
# 704: Cumulative number of states examined =  248160
# 705: Cumulative number of states examined =  248865
# 706: Cumulative number of states examined =  249571
# 707: Cumulative number of states examined =  250278
# 708: Cumulative number of states examined =  250986
# 709: Cumulative number of states examined =  251695
# 710: Cumulative number of states examined =  252405
# 711: Cumulative number of states examined =  253116
# 712: Cumulative number of states examined =  253828
# 713: Cumulative number of states examined =  254541
# 714: Cumulative number of states examined =  255255
# 715: Cumulative number of states examined =  255970
# 716: Cumulative number of states examined =  256686
# 717: Cumulative number of states examined =  257403
# 718: Cumulative number of states examined =  258121
# 719: Cumulative number of states examined =  258840
# 720: Cumulative number of states examined =  259560
# 721: Cumulative number of states examined =  260281
# 722: Cumulative number of states examined =  261003
# 723: Cumulative number of states examined =  261726
# 724: Cumulative number of states examined =  262450
# 725: Cumulative number of states examined =  263175
# 726: Cumulative number of states examined =  263901
# 727: Cumulative number of states examined =  264628
# 728: Cumulative number of states examined =  265356
# 729: Cumulative number of states examined =  266085
# 730: Cumulative number of states examined =  266815
# 731: Cumulative number of states examined =  267546
# 732: Cumulative number of states examined =  268278
# 733: Cumulative number of states examined =  269011
# 734: Cumulative number of states examined =  269745
# 735: Cumulative number of states examined =  270480
# 736: Cumulative number of states examined =  271216
# 737: Cumulative number of states examined =  271953
# 738: Cumulative number of states examined =  272691
# 739: Cumulative number of states examined =  273430
# 740: Cumulative number of states examined =  274170
# 741: Cumulative number of states examined =  274911
# 742: Cumulative number of states examined =  275653
# 743: Cumulative number of states examined =  276396
# 744: Cumulative number of states examined =  277140
# 745: Cumulative number of states examined =  277885
# 746: Cumulative number of states examined =  278631
# 747: Cumulative number of states examined =  279378
# 748: Cumulative number of states examined =  280126
# 749: Cumulative number of states examined =  280875
# 750: Cumulative number of states examined =  281625
# 751: Cumulative number of states examined =  282376
# 752: Cumulative number of states examined =  283128
# 753: Cumulative number of states examined =  283881
# 754: Cumulative number of states examined =  284635
# 755: Cumulative number of states examined =  285390
# 756: Cumulative number of states examined =  286146
# 757: Cumulative number of states examined =  286903
# 758: Cumulative number of states examined =  287661
# 759: Cumulative number of states examined =  288420
# 760: Cumulative number of states examined =  289180
# 761: Cumulative number of states examined =  289941
# 762: Cumulative number of states examined =  290703
# 763: Cumulative number of states examined =  291466
# 764: Cumulative number of states examined =  292230
# 765: Cumulative number of states examined =  292995
# 766: Cumulative number of states examined =  293761
# 767: Cumulative number of states examined =  294528
# 768: Cumulative number of states examined =  295296
# 769: Cumulative number of states examined =  296065
# 770: Cumulative number of states examined =  296835
# 771: Cumulative number of states examined =  297606
# 772: Cumulative number of states examined =  298378
# 773: Cumulative number of states examined =  299151
# 774: Cumulative number of states examined =  299925
# 775: Cumulative number of states examined =  300700
# 776: Cumulative number of states examined =  301476
# 777: Cumulative number of states examined =  302253
# 778: Cumulative number of states examined =  303031
# 779: Cumulative number of states examined =  303810
# 780: Cumulative number of states examined =  304590
# 781: Cumulative number of states examined =  305371
# 782: Cumulative number of states examined =  306153
# 783: Cumulative number of states examined =  306936
# 784: Cumulative number of states examined =  307720
# 785: Cumulative number of states examined =  308505
# 786: Cumulative number of states examined =  309291
# 787: Cumulative number of states examined =  310078
# 788: Cumulative number of states examined =  310866
# 789: Cumulative number of states examined =  311655
# 790: Cumulative number of states examined =  312445
# 791: Cumulative number of states examined =  313236
# 792: Cumulative number of states examined =  314028
# 793: Cumulative number of states examined =  314821
# 794: Cumulative number of states examined =  315615
# 795: Cumulative number of states examined =  316410
# 796: Cumulative number of states examined =  317206
# 797: Cumulative number of states examined =  318003
# 798: Cumulative number of states examined =  318801
# 799: Cumulative number of states examined =  319600
# 800: Cumulative number of states examined =  320400
# 801: Cumulative number of states examined =  321201
# 802: Cumulative number of states examined =  322003
# 803: Cumulative number of states examined =  322806
# 804: Cumulative number of states examined =  323610
# 805: Cumulative number of states examined =  324415
# 806: Cumulative number of states examined =  325221
# 807: Cumulative number of states examined =  326028
# 808: Cumulative number of states examined =  326836
# 809: Cumulative number of states examined =  327645
# 810: Cumulative number of states examined =  328455
# 811: Cumulative number of states examined =  329266
# 812: Cumulative number of states examined =  330078
# 813: Cumulative number of states examined =  330891
# 814: Cumulative number of states examined =  331705
# 815: Cumulative number of states examined =  332520
# 816: Cumulative number of states examined =  333336
# 817: Cumulative number of states examined =  334153
# 818: Cumulative number of states examined =  334971
# 819: Cumulative number of states examined =  335790
# 820: Cumulative number of states examined =  336610
# 821: Cumulative number of states examined =  337431
# 822: Cumulative number of states examined =  338253
# 823: Cumulative number of states examined =  339076
# 824: Cumulative number of states examined =  339900
# 825: Cumulative number of states examined =  340725
# 826: Cumulative number of states examined =  341551
# 827: Cumulative number of states examined =  342378
# 828: Cumulative number of states examined =  343206
# 829: Cumulative number of states examined =  344035
# 830: Cumulative number of states examined =  344865
# 831: Cumulative number of states examined =  345696
# 832: Cumulative number of states examined =  346528
# 833: Cumulative number of states examined =  347361
# 834: Cumulative number of states examined =  348195
# 835: Cumulative number of states examined =  349030
# 836: Cumulative number of states examined =  349866
# 837: Cumulative number of states examined =  350703
# 838: Cumulative number of states examined =  351541
# 839: Cumulative number of states examined =  352380
# 840: Cumulative number of states examined =  353220
# 841: Cumulative number of states examined =  354061
# 842: Cumulative number of states examined =  354903
# 843: Cumulative number of states examined =  355746
# 844: Cumulative number of states examined =  356590
# 845: Cumulative number of states examined =  357435
# 846: Cumulative number of states examined =  358281
# 847: Cumulative number of states examined =  359128
# 848: Cumulative number of states examined =  359976
# 849: Cumulative number of states examined =  360825
# 850: Cumulative number of states examined =  361675
# 851: Cumulative number of states examined =  362526
# 852: Cumulative number of states examined =  363378
# 853: Cumulative number of states examined =  364231
# 854: Cumulative number of states examined =  365085
# 855: Cumulative number of states examined =  365940
# 856: Cumulative number of states examined =  366796
# 857: Cumulative number of states examined =  367653
# 858: Cumulative number of states examined =  368511
# 859: Cumulative number of states examined =  369370
# 860: Cumulative number of states examined =  370230
# 861: Cumulative number of states examined =  371091
# 862: Cumulative number of states examined =  371953
# 863: Cumulative number of states examined =  372816
# 864: Cumulative number of states examined =  373680
# 865: Cumulative number of states examined =  374545
# 866: Cumulative number of states examined =  375411
# 867: Cumulative number of states examined =  376278
# 868: Cumulative number of states examined =  377146
# 869: Cumulative number of states examined =  378015
# 870: Cumulative number of states examined =  378885
# 871: Cumulative number of states examined =  379756
# 872: Cumulative number of states examined =  380628
# 873: Cumulative number of states examined =  381501
# 874: Cumulative number of states examined =  382375
# 875: Cumulative number of states examined =  383250
# 876: Cumulative number of states examined =  384126
# 877: Cumulative number of states examined =  385003
# 878: Cumulative number of states examined =  385881
# 879: Cumulative number of states examined =  386760
# 880: Cumulative number of states examined =  387640
# 881: Cumulative number of states examined =  388521
# 882: Cumulative number of states examined =  389403
# 883: Cumulative number of states examined =  390286
# 884: Cumulative number of states examined =  391170
# 885: Cumulative number of states examined =  392055
# 886: Cumulative number of states examined =  392941
# 887: Cumulative number of states examined =  393828
# 888: Cumulative number of states examined =  394716
# 889: Cumulative number of states examined =  395605
# 890: Cumulative number of states examined =  396495
# 891: Cumulative number of states examined =  397386
# 892: Cumulative number of states examined =  398278
# 893: Cumulative number of states examined =  399171
# 894: Cumulative number of states examined =  400065
# 895: Cumulative number of states examined =  400960
# 896: Cumulative number of states examined =  401856
# 897: Cumulative number of states examined =  402753
# 898: Cumulative number of states examined =  403651
# 899: Cumulative number of states examined =  404550
# 900: Cumulative number of states examined =  405450
# 901: Cumulative number of states examined =  406351
# 902: Cumulative number of states examined =  407253
# 903: Cumulative number of states examined =  408156
# 904: Cumulative number of states examined =  409060
# 905: Cumulative number of states examined =  409965
# 906: Cumulative number of states examined =  410871
# 907: Cumulative number of states examined =  411778
# 908: Cumulative number of states examined =  412686
# 909: Cumulative number of states examined =  413595
# 910: Cumulative number of states examined =  414505
# 911: Cumulative number of states examined =  415416
# 912: Cumulative number of states examined =  416328
# 913: Cumulative number of states examined =  417241
# 914: Cumulative number of states examined =  418155
# 915: Cumulative number of states examined =  419070
# 916: Cumulative number of states examined =  419986
# 917: Cumulative number of states examined =  420903
# 918: Cumulative number of states examined =  421821
# 919: Cumulative number of states examined =  422740
# 920: Cumulative number of states examined =  423660
# 921: Cumulative number of states examined =  424581
# 922: Cumulative number of states examined =  425503
# 923: Cumulative number of states examined =  426426
# 924: Cumulative number of states examined =  427350
# 925: Cumulative number of states examined =  428275
# 926: Cumulative number of states examined =  429201
# 927: Cumulative number of states examined =  430128
# 928: Cumulative number of states examined =  431056
# 929: Cumulative number of states examined =  431985
# 930: Cumulative number of states examined =  432915
# 931: Cumulative number of states examined =  433846
# 932: Cumulative number of states examined =  434778
# 933: Cumulative number of states examined =  435711
# 934: Cumulative number of states examined =  436645
# 935: Cumulative number of states examined =  437580
# 936: Cumulative number of states examined =  438516
# ...
# 6680: Cumulative number of states examined =  22314540
# 6681: Cumulative number of states examined =  22321221
# 6682: Cumulative number of states examined =  22327903
# 6683: Cumulative number of states examined =  22334586
# 6684: Cumulative number of states examined =  22341270
# 6685: Cumulative number of states examined =  22347955
# 6686: Cumulative number of states examined =  22354641
# 6687: Cumulative number of states examined =  22361328
# 6688: Cumulative number of states examined =  22368016
# 6689: Cumulative number of states examined =  22374705
# 6690: Cumulative number of states examined =  22381395
# 6691: Cumulative number of states examined =  22388086
# 6692: Cumulative number of states examined =  22394778
# 6693: Cumulative number of states examined =  22401471
# 6694: Cumulative number of states examined =  22408165
# 6695: Cumulative number of states examined =  22414860
# 6696: Cumulative number of states examined =  22421556
# 6697: Cumulative number of states examined =  22428253
# 6698: Cumulative number of states examined =  22434951
# 6699: Cumulative number of states examined =  22441650
# 6700: Cumulative number of states examined =  22448350
# 6701: Cumulative number of states examined =  22455051
# 6702: Cumulative number of states examined =  22461753
# 6703: Cumulative number of states examined =  22468456
# 6704: Cumulative number of states examined =  22475160
# 6705: Cumulative number of states examined =  22481865
# 6706: Cumulative number of states examined =  22488571
# 6707: Cumulative number of states examined =  22495278
# 6708: Cumulative number of states examined =  22501986
# 6709: Cumulative number of states examined =  22508695
# 6710: Cumulative number of states examined =  22515405
# 6711: Cumulative number of states examined =  22522116
# 6712: Cumulative number of states examined =  22528828
# 6713: Cumulative number of states examined =  22535541
# 6714: Cumulative number of states examined =  22542255
# 6715: Cumulative number of states examined =  22548970
# 6716: Cumulative number of states examined =  22555686
# 6717: Cumulative number of states examined =  22562403
# 6718: Cumulative number of states examined =  22569121
# 6719: Cumulative number of states examined =  22575840
# 6720: Cumulative number of states examined =  22582560
# 6721: Cumulative number of states examined =  22589281
# 6722: Cumulative number of states examined =  22596003
# 6723: Cumulative number of states examined =  22602726
# 6724: Cumulative number of states examined =  22609450
# 6725: Cumulative number of states examined =  22616175
# 6726: Cumulative number of states examined =  22622901
# 6727: Cumulative number of states examined =  22629628
# 6728: Cumulative number of states examined =  22636356
# 6729: Cumulative number of states examined =  22643085
# 6730: Cumulative number of states examined =  22649815
# 6731: Cumulative number of states examined =  22656546
# 6732: Cumulative number of states examined =  22663278
# 6733: Cumulative number of states examined =  22670011
# 6734: Cumulative number of states examined =  22676745
# 6735: Cumulative number of states examined =  22683480
# 6736: Cumulative number of states examined =  22690216
# 6737: Cumulative number of states examined =  22696953
# 6738: Cumulative number of states examined =  22703691
# 6739: Cumulative number of states examined =  22710430
# 6740: Cumulative number of states examined =  22717170
# 6741: Cumulative number of states examined =  22723911
# 6742: Cumulative number of states examined =  22730653
# 6743: Cumulative number of states examined =  22737396
# 6744: Cumulative number of states examined =  22744140
# 6745: Cumulative number of states examined =  22750885
# 6746: Cumulative number of states examined =  22757631
# 6747: Cumulative number of states examined =  22764378
# 6748: Cumulative number of states examined =  22771126
# 6749: Cumulative number of states examined =  22777875
# 6750: Cumulative number of states examined =  22784625
# 6751: Cumulative number of states examined =  22791376
# 6752: Cumulative number of states examined =  22798128
# 6753: Cumulative number of states examined =  22804881
# 6754: Cumulative number of states examined =  22811635
# 6755: Cumulative number of states examined =  22818390
# 6756: Cumulative number of states examined =  22825146
# 6757: Cumulative number of states examined =  22831903
# 6758: Cumulative number of states examined =  22838661
# 6759: Cumulative number of states examined =  22845420
# 6760: Cumulative number of states examined =  22852180
# 6761: Cumulative number of states examined =  22858941
# 6762: Cumulative number of states examined =  22865703
# 6763: Cumulative number of states examined =  22872466
# 6764: Cumulative number of states examined =  22879230
# 6765: Cumulative number of states examined =  22885995
# 6766: Cumulative number of states examined =  22892761
# 6767: Cumulative number of states examined =  22899528
# 6768: Cumulative number of states examined =  22906296
# 6769: Cumulative number of states examined =  22913065
# 6770: Cumulative number of states examined =  22919835
# 6771: Cumulative number of states examined =  22926606
# 6772: Cumulative number of states examined =  22933378
# 6773: Cumulative number of states examined =  22940151
# 6774: Cumulative number of states examined =  22946925
# 6775: Cumulative number of states examined =  22953700
# 6776: Cumulative number of states examined =  22960476
# 6777: Cumulative number of states examined =  22967253
# 6778: Cumulative number of states examined =  22974031
# 6779: Cumulative number of states examined =  22980810
# 6780: Cumulative number of states examined =  22987590
# 6781: Cumulative number of states examined =  22994371
# 6782: Cumulative number of states examined =  23001153
# 6783: Cumulative number of states examined =  23007936
# 6784: Cumulative number of states examined =  23014720
# 6785: Cumulative number of states examined =  23021505
# 6786: Cumulative number of states examined =  23028291
# 6787: Cumulative number of states examined =  23035078
# 6788: Cumulative number of states examined =  23041866
# 6789: Cumulative number of states examined =  23048655
# 6790: Cumulative number of states examined =  23055445
# 6791: Cumulative number of states examined =  23062236
# 6792: Cumulative number of states examined =  23069028
# 6793: Cumulative number of states examined =  23075821
# 6794: Cumulative number of states examined =  23082615
# 6795: Cumulative number of states examined =  23089410
# 6796: Cumulative number of states examined =  23096206
# 6797: Cumulative number of states examined =  23103003
# 6798: Cumulative number of states examined =  23109801
# 6799: Cumulative number of states examined =  23116600
# 6800: Cumulative number of states examined =  23123400
# 6801: Cumulative number of states examined =  23130201
# 6802: Cumulative number of states examined =  23137003
# 6803: Cumulative number of states examined =  23143806
# 6804: Cumulative number of states examined =  23150610
# 6805: Cumulative number of states examined =  23157415
# 6806: Cumulative number of states examined =  23164221
# 6807: Cumulative number of states examined =  23171028
# 6808: Cumulative number of states examined =  23177836
# 6809: Cumulative number of states examined =  23184645
# 6810: Cumulative number of states examined =  23191455
# 6811: Cumulative number of states examined =  23198266
# 6812: Cumulative number of states examined =  23205078
# 6813: Cumulative number of states examined =  23211891
# 6814: Cumulative number of states examined =  23218705
# 6815: Cumulative number of states examined =  23225520
# 6816: Cumulative number of states examined =  23232336
# 6817: Cumulative number of states examined =  23239153
# 6818: Cumulative number of states examined =  23245971
# 6819: Cumulative number of states examined =  23252790
# 6820: Cumulative number of states examined =  23259610
# 6821: Cumulative number of states examined =  23266431
# 6822: Cumulative number of states examined =  23273253
# 6823: Cumulative number of states examined =  23280076
# 6824: Cumulative number of states examined =  23286900
# 6825: Cumulative number of states examined =  23293725
# 6826: Cumulative number of states examined =  23300551
# 6827: Cumulative number of states examined =  23307378
# 6828: Cumulative number of states examined =  23314206
# 6829: Cumulative number of states examined =  23321035
# 6830: Cumulative number of states examined =  23327865
# 6831: Cumulative number of states examined =  23334696
# 6832: Cumulative number of states examined =  23341528
# 6833: Cumulative number of states examined =  23348361
# 6834: Cumulative number of states examined =  23355195
# 6835: Cumulative number of states examined =  23362030
# 6836: Cumulative number of states examined =  23368866
# 6837: Cumulative number of states examined =  23375703
# 6838: Cumulative number of states examined =  23382541
# 6839: Cumulative number of states examined =  23389380
# 6840: Cumulative number of states examined =  23396220
# 6841: Cumulative number of states examined =  23403061
# 6842: Cumulative number of states examined =  23409903
# 6843: Cumulative number of states examined =  23416746
# 6844: Cumulative number of states examined =  23423590
# 6845: Cumulative number of states examined =  23430435
# 6846: Cumulative number of states examined =  23437281
# 6847: Cumulative number of states examined =  23444128
# 6848: Cumulative number of states examined =  23450976
# 6849: Cumulative number of states examined =  23457825
# 6850: Cumulative number of states examined =  23464675
# 6851: Cumulative number of states examined =  23471526
# 6852: Cumulative number of states examined =  23478378
# 6853: Cumulative number of states examined =  23485231
# 6854: Cumulative number of states examined =  23492085
# 6855: Cumulative number of states examined =  23498940
# 6856: Cumulative number of states examined =  23505796
# 6857: Cumulative number of states examined =  23512653
# 6858: Cumulative number of states examined =  23519511
# 6859: Cumulative number of states examined =  23526370
# 6860: Cumulative number of states examined =  23533230
# 6861: Cumulative number of states examined =  23540091
# 6862: Cumulative number of states examined =  23546953
# 6863: Cumulative number of states examined =  23553816
# 6864: Cumulative number of states examined =  23560680
# 6865: Cumulative number of states examined =  23567545
# 6866: Cumulative number of states examined =  23574411
# 6867: Cumulative number of states examined =  23581278
# 6868: Cumulative number of states examined =  23588146
# 6869: Cumulative number of states examined =  23595015
# 6870: Cumulative number of states examined =  23601885
# 6871: Cumulative number of states examined =  23608756
# 6872: Cumulative number of states examined =  23615628
# 6873: Cumulative number of states examined =  23622501
# 6874: Cumulative number of states examined =  23629375
# 6875: Cumulative number of states examined =  23636250
# 6876: Cumulative number of states examined =  23643126
# 6877: Cumulative number of states examined =  23650003
# 6878: Cumulative number of states examined =  23656881
# 6879: Cumulative number of states examined =  23663760
# 6880: Cumulative number of states examined =  23670640
# 6881: Cumulative number of states examined =  23677521
# 6882: Cumulative number of states examined =  23684403
# 6883: Cumulative number of states examined =  23691286
# 6884: Cumulative number of states examined =  23698170
# 6885: Cumulative number of states examined =  23705055
# 6886: Cumulative number of states examined =  23711941
# 6887: Cumulative number of states examined =  23718828
# 6888: Cumulative number of states examined =  23725716
# 6889: Cumulative number of states examined =  23732605
# 6890: Cumulative number of states examined =  23739495
# 6891: Cumulative number of states examined =  23746386
# 6892: Cumulative number of states examined =  23753278
# 6893: Cumulative number of states examined =  23760171
# 6894: Cumulative number of states examined =  23767065
# 6895: Cumulative number of states examined =  23773960
# 6896: Cumulative number of states examined =  23780856
# 6897: Cumulative number of states examined =  23787753
# 6898: Cumulative number of states examined =  23794651
# 6899: Cumulative number of states examined =  23801550
# 6900: Cumulative number of states examined =  23808450
# 6901: Cumulative number of states examined =  23815351
# 6902: Cumulative number of states examined =  23822253
# 6903: Cumulative number of states examined =  23829156
# 6904: Cumulative number of states examined =  23836060
# 6905: Cumulative number of states examined =  23842965
# 6906: Cumulative number of states examined =  23849871
# 6907: Cumulative number of states examined =  23856778
# 6908: Cumulative number of states examined =  23863686
# 6909: Cumulative number of states examined =  23870595
# 6910: Cumulative number of states examined =  23877505
# 6911: Cumulative number of states examined =  23884416
# 6912: Cumulative number of states examined =  23891328
# 6913: Cumulative number of states examined =  23898241
# 6914: Cumulative number of states examined =  23905155
# 6915: Cumulative number of states examined =  23912070
# 6916: Cumulative number of states examined =  23918986
# 6917: Cumulative number of states examined =  23925903
# 6918: Cumulative number of states examined =  23932821
# 6919: Cumulative number of states examined =  23939740
# 6920: Cumulative number of states examined =  23946660
# 6921: Cumulative number of states examined =  23953581
# 6922: Cumulative number of states examined =  23960503
# 6923: Cumulative number of states examined =  23967426
# 6924: Cumulative number of states examined =  23974350
# 6925: Cumulative number of states examined =  23981275
# 6926: Cumulative number of states examined =  23988201
# 6927: Cumulative number of states examined =  23995128
# 6928: Cumulative number of states examined =  24002056
# 6929: Cumulative number of states examined =  24008985
# 6930: Cumulative number of states examined =  24015915
# 6931: Cumulative number of states examined =  24022846
# 6932: Cumulative number of states examined =  24029778
# 6933: Cumulative number of states examined =  24036711
# 6934: Cumulative number of states examined =  24043645
# 6935: Cumulative number of states examined =  24050580
# 6936: Cumulative number of states examined =  24057516
# 6937: Cumulative number of states examined =  24064453
# 6938: Cumulative number of states examined =  24071391
# 6939: Cumulative number of states examined =  24078330
# 6940: Cumulative number of states examined =  24085270
# 6941: Cumulative number of states examined =  24092211
# 6942: Cumulative number of states examined =  24099153
# 6943: Cumulative number of states examined =  24106096
# 6944: Cumulative number of states examined =  24113040
# 6945: Cumulative number of states examined =  24119985
# 6946: Cumulative number of states examined =  24126931
# 6947: Cumulative number of states examined =  24133878
# 6948: Cumulative number of states examined =  24140826
# 6949: Cumulative number of states examined =  24147775
# 6950: Cumulative number of states examined =  24154725
# 6951: Cumulative number of states examined =  24161676
# 6952: Cumulative number of states examined =  24168628
# 6953: Cumulative number of states examined =  24175581
# 6954: Cumulative number of states examined =  24182535
# 6955: Cumulative number of states examined =  24189490
# 6956: Cumulative number of states examined =  24196446
# 6957: Cumulative number of states examined =  24203403
# 6958: Cumulative number of states examined =  24210361
# 6959: Cumulative number of states examined =  24217320
# 6960: Cumulative number of states examined =  24224280
# 6961: Cumulative number of states examined =  24231241
# 6962: Cumulative number of states examined =  24238203
# 6963: Cumulative number of states examined =  24245166
# 6964: Cumulative number of states examined =  24252130
# 6965: Cumulative number of states examined =  24259095
# 6966: Cumulative number of states examined =  24266061
# 6967: Cumulative number of states examined =  24273028
# 6968: Cumulative number of states examined =  24279996
# 6969: Cumulative number of states examined =  24286965

# %% [markdown]
# ### Part 4
# - Implement either the Uniform-Cost-Search or GRAPHSEARCH algorithm and use it to perform a breadth- first search of sliding-tile problems.
# - Implement a main program to accept a sliding-tile puzzle and solve it using your implementation. Print the **start and goal state**; the **solution** and **solution length**; and the **number of states generated and explored**.

# %%
def BFS(state, goal):
    list_state = state['start'].tolist()
    queue = deque([(list_state, 0,[])])

    print("start:")
    for row in list_state:
        print(" ".join(map(str, row)))
    print()
    print("goal:")
    for row in goal:
        print(" ".join(map(str, row)))
    print()

    explored = set()
    total_nodes_generated = 0
    cumulative_nodes = 0

    while queue:
        current_state, depth, path = queue.popleft()
        total_nodes_generated += 1

        if current_state == goal:
            print("Solution length", depth)
            print("Nodes generated:", total_nodes_generated)
            print("Nodes examined:", cumulative_nodes)
            for move in path:
                print(f"(node '{move}')")
            print(")")
            return
        
        
        explored.add(tuple(map(tuple, current_state)))

        # Convert current_state back to DataFrame
        df = pd.DataFrame({'start': current_state})

        # Get the applicable moves and apply them
        result = move_and_apply(df, applicable_moves(df), False)
        cumulative_nodes += len(explored)

        moves = result
        for i, descendant in enumerate(result):
            descendant_tuple = tuple(map(tuple, descendant))  # Convert lists to tuples
            if descendant_tuple not in explored and descendant not in queue:
                new_path = path + [moves[i]]
                queue.append((descendant, depth + 1,new_path))

# %%
BFS(df1,goal)
# Out:
# start:
# 3 1 2
# 0 4 5
# 6 7 8
#
# goal:
# 0 1 2
# 3 4 5
# 6 7 8
#
# Solution length 1
# Nodes generated: 3
# Nodes examined: 3
# (node '[[0, 1, 2], [3, 4, 5], [6, 7, 8]]')
# )

# %%
test_state = [[7, 2, 4],[5, 0, 6],[8, 3, 1]]
testdf = pd.DataFrame({'start': test_state})
BFS(testdf,goal)
# Out:
# start:
# 7 2 4
# 5 0 6
# 8 3 1
#
# goal:
# 0 1 2
# 3 4 5
# 6 7 8
#
# Solution length 26
# Nodes generated: 407593
# Nodes examined: 41768986886
# (node '[[7, 2, 4], [0, 5, 6], [8, 3, 1]]')
# (node '[[0, 2, 4], [7, 5, 6], [8, 3, 1]]')
# (node '[[2, 0, 4], [7, 5, 6], [8, 3, 1]]')
# (node '[[2, 5, 4], [7, 0, 6], [8, 3, 1]]')
# (node '[[2, 5, 4], [7, 6, 0], [8, 3, 1]]')
# (node '[[2, 5, 4], [7, 6, 1], [8, 3, 0]]')
# (node '[[2, 5, 4], [7, 6, 1], [8, 0, 3]]')
# (node '[[2, 5, 4], [7, 6, 1], [0, 8, 3]]')
# (node '[[2, 5, 4], [0, 6, 1], [7, 8, 3]]')
# (node '[[2, 5, 4], [6, 0, 1], [7, 8, 3]]')
# (node '[[2, 5, 4], [6, 1, 0], [7, 8, 3]]')
# (node '[[2, 5, 4], [6, 1, 3], [7, 8, 0]]')
# (node '[[2, 5, 4], [6, 1, 3], [7, 0, 8]]')
# (node '[[2, 5, 4], [6, 1, 3], [0, 7, 8]]')
# (node '[[2, 5, 4], [0, 1, 3], [6, 7, 8]]')
# (node '[[2, 5, 4], [1, 0, 3], [6, 7, 8]]')
# (node '[[2, 5, 4], [1, 3, 0], [6, 7, 8]]')
# (node '[[2, 5, 0], [1, 3, 4], [6, 7, 8]]')
# (node '[[2, 0, 5], [1, 3, 4], [6, 7, 8]]')
# (node '[[0, 2, 5], [1, 3, 4], [6, 7, 8]]')
# (node '[[1, 2, 5], [0, 3, 4], [6, 7, 8]]')
# (node '[[1, 2, 5], [3, 0, 4], [6, 7, 8]]')
# (node '[[1, 2, 5], [3, 4, 0], [6, 7, 8]]')
# (node '[[1, 2, 0], [3, 4, 5], [6, 7, 8]]')
# (node '[[1, 0, 2], [3, 4, 5], [6, 7, 8]]')
# (node '[[0, 1, 2], [3, 4, 5], [6, 7, 8]]')
# )

# %% [markdown]
# ### Part 5
# -

# %%
import heapq

def find_position(goal, value):
    for i in range(len(goal)):
        for j in range(len(goal[i])):
            if goal[i][j] == value:
                return i, j


def heuristic_manhattan(state, goal):
    total_distance = 0
    for i in range(len(state)):
        for j in range(len(state[i])):
            value = state[i][j]
            if value != 0 and value != goal[i][j]:
                _i, _j = find_position(goal, value)
                total_distance += abs(i - _i) + abs(j - _j)
    return total_distance

def A_Search(initial_state: pd.DataFrame, goal_state):
    list_state = initial_state['start'].tolist()
    priority_queue = []
    heapq.heappush(priority_queue, (heuristic_manhattan(list_state, goal_state), 0, list_state, []))
    explored = set()
    total_nodes_generated = 0
    cumulative_nodes = 0

    while priority_queue:
        _, depth, current_state, path = heapq.heappop(priority_queue)
        total_nodes_generated += 1

        if current_state == goal_state:
            print("Solution length", depth)
            print("Nodes generated:", total_nodes_generated)
            print("Nodes examined:", cumulative_nodes)
            print("Solution path:", path)
            return path

        explored.add(tuple(map(tuple, current_state)))
        df = pd.DataFrame({'start': current_state})
        result = move_and_apply(df, applicable_moves(df), False)
        cumulative_nodes += len(explored)

        for descendant in result:
            descendant_tuple = tuple(map(tuple, descendant))
            if descendant_tuple not in explored:
                heapq.heappush(
                    priority_queue,
                    (
                        depth + 1 + heuristic_manhattan(descendant, goal_state),
                        depth + 1,
                        descendant,
                        path + [descendant]
                    )
                )

    print("\nNo result found")

# %%
A_Search(df1,goal)
# Out:
# Solution length 1
# Nodes generated: 2
# Nodes examined: 1
# Solution path: [[[0, 1, 2], [3, 4, 5], [6, 7, 8]]]
# [[[0, 1, 2], [3, 4, 5], [6, 7, 8]]]

# %%
A_Search(testdf,goal)
# Out:
# Solution length 26
# Nodes generated: 5080
# Nodes examined: 10991572
# Solution path: [[[7, 2, 4], [0, 5, 6], [8, 3, 1]], [[0, 2, 4], [7, 5, 6], [8, 3, 1]], [[2, 0, 4], [7, 5, 6], [8, 3, 1]], [[2, 5, 4], [7, 0, 6], [8, 3, 1]], [[2, 5, 4], [7, 3, 6], [8, 0, 1]], [[2, 5, 4], [7, 3, 6], [0, 8, 1]], [[2, 5, 4], [0, 3, 6], [7, 8, 1]], [[2, 5, 4], [3, 0, 6], [7, 8, 1]], [[2, 5, 4], [3, 6, 0], [7, 8, 1]], [[2, 5, 0], [3, 6, 4], [7, 8, 1]], [[2, 0, 5], [3, 6, 4], [7, 8, 1]], [[0, 2, 5], [3, 6, 4], [7, 8, 1]], [[3, 2, 5], [0, 6, 4], [7, 8, 1]], [[3, 2, 5], [6, 0, 4], [7, 8, 1]], [[3, 2, 5], [6, 4, 0], [7, 8, 1]], [[3, 2, 5], [6, 4, 1], [7, 8, 0]], [[3, 2, 5], [6, 4, 1], [7, 0, 8]], [[3, 2, 5], [6, 0, 1], [7, 4, 8]], [[3, 2, 5], [6, 1, 0], [7, 4, 8]], [[3, 2, 0], [6, 1, 5], [7, 4, 8]], [[3, 0, 2], [6, 1, 5], [7, 4, 8]], [[3, 1, 2], [6, 0, 5], [7, 4, 8]], [[3, 1, 2], [6, 4, 5], [7, 0, 8]], [[3, 1, 2], [6, 4, 5], [0, 7, 8]], [[3, 1, 2], [0, 4, 5], [6, 7, 8]], [[0, 1, 2], [3, 4, 5], [6, 7, 8]]]
# [[[7, 2, 4], [0, 5, 6], [8, 3, 1]],
#  [[0, 2, 4], [7, 5, 6], [8, 3, 1]],
#  [[2, 0, 4], [7, 5, 6], [8, 3, 1]],
#  [[2, 5, 4], [7, 0, 6], [8, 3, 1]],
#  [[2, 5, 4], [7, 3, 6], [8, 0, 1]],
#  [[2, 5, 4], [7, 3, 6], [0, 8, 1]],
#  [[2, 5, 4], [0, 3, 6], [7, 8, 1]],
#  [[2, 5, 4], [3, 0, 6], [7, 8, 1]],
#  [[2, 5, 4], [3, 6, 0], [7, 8, 1]],
#  [[2, 5, 0], [3, 6, 4], [7, 8, 1]],
#  [[2, 0, 5], [3, 6, 4], [7, 8, 1]],
#  [[0, 2, 5], [3, 6, 4], [7, 8, 1]],
#  [[3, 2, 5], [0, 6, 4], [7, 8, 1]],
#  [[3, 2, 5], [6, 0, 4], [7, 8, 1]],
#  [[3, 2, 5], [6, 4, 0], [7, 8, 1]],
#  [[3, 2, 5], [6, 4, 1], [7, 8, 0]],
#  [[3, 2, 5], [6, 4, 1], [7, 0, 8]],
#  [[3, 2, 5], [6, 0, 1], [7, 4, 8]],
#  [[3, 2, 5], [6, 1, 0], [7, 4, 8]],
#  [[3, 2, 0], [6, 1, 5], [7, 4, 8]],
#  [[3, 0, 2], [6, 1, 5], [7, 4, 8]],
#  [[3, 1, 2], [6, 0, 5], [7, 4, 8]],
#  [[3, 1, 2], [6, 4, 5], [7, 0, 8]],
#  [[3, 1, 2], [6, 4, 5], [0, 7, 8]],
#  [[3, 1, 2], [0, 4, 5], [6, 7, 8]],
#  [[0, 1, 2], [3, 4, 5], [6, 7, 8]]]
